# %% [markdown]
# ## EAS 503 Homework 4 Submission
# Name - _Enter your name here_
#
# **Make sure that you rename the notebook file to *replacewithubitname*_eas503_hw4.ipynb**
#
#
# ### Submission Details
# ### Submit on UBLearns
#
# * **Due Date** - December 5, 2018 by 11.59 PM PST. All assignments have to be submitted using UBLearns.
# * **Number of Problems** - 1
# * **Maximum points** - 50
# * **Collaboration policy**
#  - Every student has to submit individual homeworks
#  - Any collaboration, in the form of discussion, with other members of the class is permitted, as long as the names of the collaborating members are explicitly stated on top of the submitted homework.
#  - Any overlap with another submission or material from Internet will be awarded an F.
# * **Late submission policy** - _No late submissions allowed_
# * **Submission Format** - Enter code for each problem in the appropriate cell below. You may use multiple cells for a single problem to improve readability.

# %% [markdown]
# ### Problem 1 - Chicago Crime Dataset (50 points)
#
# Recall the Chicago Crime Data that was used in HW3. In this HW you are provided with 3 data files namely `chicago_crime_data_1.csv`, `chicago_crime_data_2.csv` and `primary_type_id.csv`.  The `chicago_crime_data_1.csv` contains data pertaining to the details of the crime and the `chicago_crime_data_2.csv` has information about the location and type. Both the datasets have the Crime ID as the primary indicator.
#
# The `primary_type_id.csv` contains the mapping between the primary crime type to their corresponding ID.
#
# ### Importing data
# From the command line, execute the following command (assuming your current directory contains the homework files):
# ```bash
# mysql --local-infile -u root -proot < setupdb.sql
# ```
# > _Note_: In some systems you might not need the `--local-infile` option, it depends on the mode in which the database server is running. If you are running it in default mode, you most likely will need that option
#
# The database is needed to verify that your queries are running correctly. But you do not have to submit the output of your queries. You only have to submit the queries and in some cases, the algebraic expression and the expression trees.
# ### Problems
# You will be asked to create a single sql query that will result in the desired output. Wherever required, provide the algebraic expressions and expression trees.
#
# 1. How many arrests were made for domestic crimes? (Query)
#
# 2. Subset the list of crimes that occured at SIDEWALK and an arrest has been made. (Query, algebraic expression and expression tree)
#
# 3. How many arrests were made for domestic crimes? (Query)
#
# 4. Report all the case details available to the case number "HZ237376". (Query, algebraic expression and expression tree)
#
# 5. What is the increase in the number of crimes involving thefts (primary crime type) from 2016 to 2017? (Query)
#
# 6. List all the descriptions that occured in district 15 under the Primary Type ID = 11. Order them alphabetically. (Query)
#
# 7. Average days between the crime incident date and last updated date. (Query)
#
# 8. List the crimes that were committed on `4/30/2016` and updated on the same day. (Query, algebraic expression, expression tree)
#
# 9. Subset the list of crimes in 2016 that were domestic and occured on a `STREET` and an arrest was made. (Query, algebraic expression, expression tree)
#
# 10. Are there any crimes that involved `Telephone threats` that occured in District `10` and FBI code `30`? (Query, algebraic expression, expression tree)
#
#
# Submit the SQL query as a .txt file. The algebraic expressions and expression tree can be hand written and scanned and submitted through UBLearns as a single PDF file.

# %%
#Enter your solution here
import pandas as pd

# %%
import mysql.connector
cnx = mysql.connector.connect(user='root', password="Firebender3112$", database='hw4',auth_plugin='mysql_native_password')
cursor = cnx.cursor()
df = pd.read_sql('select count(*) from CRIME_INCIDENTS where Arrest = "TRUE" AND Domestic = "TRUE"', cnx)

# %%
df
# Out:
#    count(*)
# 0     11979

# %%
# question 2
cnx = mysql.connector.connect(user='root', password="Firebender3112$", database='hw4',auth_plugin='mysql_native_password')
cursor = cnx.cursor()
df = pd.read_sql('''select distinct(ct.primary_type) from crime_details cd left join crime_incidents ci on cd.crime_id=ci.crime_id left join crime_types ct on cd.primary_type_id=ct.primary_type_id where cd.location_description = "SIDEWALK" and  ci.arrest = "True";''', cnx)

# %%
df
# Out:
#                          primary_type
# 0                   WEAPONS VIOLATION
# 1                             BATTERY
# 2                           NARCOTICS
# 3                LIQUOR LAW VIOLATION
# 4    INTERFERENCE WITH PUBLIC OFFICER
# 5              PUBLIC PEACE VIOLATION
# 6                             ROBBERY
# 7                               THEFT
# 8                         SEX OFFENSE
# 9                       OTHER OFFENSE
# 10                            ASSAULT
# 11                    CRIMINAL DAMAGE
# 12                       PROSTITUTION
# 13                  CRIMINAL TRESPASS
# 14                 DECEPTIVE PRACTICE
# 15                           GAMBLING
# 16                       INTIMIDATION
# 17                MOTOR VEHICLE THEFT
# 18                          OBSCENITY
# 19         OFFENSE INVOLVING CHILDREN
# 20                           BURGLARY
# 21                CRIM SEXUAL ASSAULT
# 22  CONCEALED CARRY LICENSE VIOLATION
# 23                         KIDNAPPING
# 24           OTHER NARCOTIC VIOLATION
# 25                   PUBLIC INDECENCY
# 26                           STALKING
# 27                              ARSON

# %%
# question 3
# same as q1

# %%
# question 4
cnx = mysql.connector.connect(user='root', password="Firebender3112$", database='hw4',auth_plugin='mysql_native_password')
cursor = cnx.cursor()
df = pd.read_sql('select * from crime_details cd NATURAL JOIN crime_incidents ci ,crime_types T WHERE cd.Case_Number = ci.Case_Number AND T.Primary_Type_ID = cd.Primary_Type_ID AND cd.Case_Number = "HZ237376"', cnx)

# %%
df
# Out:
#    Crime_ID Case_Number                 Block  IUCR Primary_Type_ID  \
# 0  10496352    HZ237376  018XX S ST LOUIS AVE   820              32
#
#       Description Location_Description  X_Coordinate  Y_Coordinate  Year  \
# 0  $500 AND UNDER            APARTMENT     1153330.0     1890820.0  2016
#
#         ...                      Date Arrest Domestic  Beat District  Ward  \
# 0       ...       2016-04-23 16:39:00  FALSE     TRUE  1021       10    24
#
#    Community_Area  FBI_Code  Primary_Type Primary_Type_ID
# 0              29       6\r         THEFT              32
#
# [1 rows x 22 columns]

# %%
# question 5
cnx = mysql.connector.connect(user='root', password="Firebender3112$", database='hw4',auth_plugin='mysql_native_password')
cursor = cnx.cursor()
df = pd.read_sql('select * from crime_details jd left join crime_incidents ji  on jd.crime_id=ji.crime_id left join crime_types jt on jd.primary_type_id=jt.primary_type_id where jd.location_description = "SIDEWALK" and  ji.arrest = "True";', cnx)

# %%
df
# Out:
#     Crime_ID Case_Number                Date Arrest Domestic  Beat  District  \
# 0      22551    HM489058 2016-06-12 19:54:00   TRUE     TRUE  1523        15
# 1      22250    HZ103309 2016-01-04 08:58:00   TRUE    FALSE  1523        15
# 68    29              25    01A\r              ...
# 69    29              25    01A\r              ...
# 70    24              25    01A\r              ...
# 71    37              25    01A\r              ...
# 72    28              25    01A\r              ...
# 73    37              25    01A\r              ...
# 74    28              25    01A\r              ...
# 75    29              25    01A\r              ...
# 76    37              25    01A\r              ...
# 77    37              25    01A\r              ...
# 78    28              25    01A\r              ...
# 79    28              25    01A\r              ...
# 80    28              25    01A\r              ...
# 81    29              25    01A\r              ...
# 82    29              25    01A\r              ...
# 83    37              25    01A\r              ...
# 84    29              25    01A\r              ...
# 85    29              25    01A\r              ...
# 86    24              25    01A\r              ...
# 87    28              25    01A\r              ...
# 88    29              25    01A\r              ...
# 89    29              25    01A\r              ...
# 90    29              25    01A\r              ...
# 91    37              25    01A\r              ...
#
#                       Block IUCR Primary_Type_ID          Description  \
# 0         001XX N LOREL AVE  110              11  FIRST DEGREE MURDER
# 1       004XX N CENTRAL AVE  110              11  FIRST DEGREE MURDER
# 2      007XX N LAVERGNE AVE  110              11  FIRST DEGREE MURDER
# 3    000XX S LEAMINGTON AVE  110              11  FIRST DEGREE MURDER
# 4       051XX W DIVISION ST  110              11  FIRST DEGREE MURDER
# 5      050XX W FERDINAND ST  110              11  FIRST DEGREE MURDER
# 6        003XX S CICERO AVE  110              11  FIRST DEGREE MURDER
# 7      010XX N LAVERGNE AVE  110              11  FIRST DEGREE MURDER
# 8          053XX W HURON ST  110              11  FIRST DEGREE MURDER
# 9       003XX N CENTRAL AVE  110              11  FIRST DEGREE MURDER
# 10      008XX N LATROBE AVE  110              11  FIRST DEGREE MURDER
# 11       049XX W MADISON ST  110              11  FIRST DEGREE MURDER
# 12        049XX W MONROE ST  110              11  FIRST DEGREE MURDER
# 13       004XX S CICERO AVE  110              11  FIRST DEGREE MURDER
# 14      053XX W HARRISON ST  110              11  FIRST DEGREE MURDER
# 15       008XX N WALLER AVE  110              11  FIRST DEGREE MURDER
# 16  049XX W WASHINGTON BLVD  110              11  FIRST DEGREE MURDER
# 17        000XX N LOREL AVE  110              11  FIRST DEGREE MURDER
# 18        054XX W WALTON ST  110              11  FIRST DEGREE MURDER
# 19     058XX W AUGUSTA BLVD  110              11  FIRST DEGREE MURDER
# 20      002XX N LARAMIE AVE  110              11  FIRST DEGREE MURDER
# 21       053XX W GLADYS AVE  110              11  FIRST DEGREE MURDER
# 22         049XX W HURON ST  110              11  FIRST DEGREE MURDER
# 23        048XX W WALTON ST  110              11  FIRST DEGREE MURDER
# 24        048XX W MONROE ST  110              11  FIRST DEGREE MURDER
# 25    009XX N MASSASOIT AVE  110              11  FIRST DEGREE MURDER
# 26     005XX N LAVERGNE AVE  110              11  FIRST DEGREE MURDER
# 27       006XX S CICERO AVE  110              11  FIRST DEGREE MURDER
# 28        010XX N LAMON AVE  110              11  FIRST DEGREE MURDER
# 29     005XX N LAVERGNE AVE  110              11  FIRST DEGREE MURDER
# ..                      ...  ...             ...                  ...
# 62          055XX W RICE ST  110              11  FIRST DEGREE MURDER
